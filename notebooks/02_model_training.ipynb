# %% [markdown]
# # 02 · Model Training (Rule-Based Strategy)
#
# This notebook is a placeholder for the UPRO/SPXU Morning-Momentum Strategy, which is **rule-based** and does not require machine learning.

# %% [markdown]
# **Strategy Overview**
#
# The UPRO/SPXU duel strategy is deterministic and follows these rules:
#
# 1. **Morning Cleanup**: Close any overnight positions at 09:30
# 2. **PDT Check**: Verify we can trade without violating PDT rules
# 3. **Duel Entry**: Buy equal $ amounts of UPRO and SPXU at 09:30
# 4. **Winner Window**: Monitor 5-minute window (09:31-09:35) for 0.5% spread
# 5. **Close Loser**: Sell losing ETF when winner is declared
# 6. **Close Winner**: Exit winner at next day open OR same day close (configurable)
#
# No machine learning model is required. All logic is implemented in the backtest.

# %%
# Add parent directory to path for module imports
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from config import get_config

config = get_config()

print("=" * 60)
print("RULE-BASED STRATEGY CONFIGURATION")
print("=" * 60)
print(f"Strategy Type:       Deterministic (No ML)")
print(f"Entry Time:          09:30:00 ET")
print(f"Winner Window:       5 minutes (09:31-09:35)")
print(f"Spread Threshold:    {config.spread_threshold * 100:.2f}%")
print(f"Exit Mode:           {config.exit_mode}")
print("=" * 60)
print("\nNo model training required. Proceed to 03_backtest notebook.")

# %%
importances.head(10) if importances is not None else "No feature importances available"
