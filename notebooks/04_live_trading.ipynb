# %% [markdown]
# # 04 · Live Trading Runbook
#
# Lean notebook that loads the trained artifacts, instantiates the `LiveMomentumTrader`, and executes one live session when market conditions are satisfied.

# %% [markdown]
# > Important: run only during market hours after confirming that the latest model, features, and backtest results meet your requirements.

# %%
from pathlib import Path

from live_trading import build_trader

trader = build_trader(Path("../.env"), wait_minutes=5, spread_threshold=0.005)
print("Trader ready. Call `trader.run_session()` when the market is about to open.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pathlib import Path
# ----> 3 from live_trading import build_trader
#       5 trader = build_trader(Path("../.env"), wait_minutes=5, spread_threshold=0.005)
#       6 print("Trader ready. Call `trader.run_session()` when the market is about to open.")
#
# ModuleNotFoundError: No module named 'live_trading'

# %%
# Uncomment when you are ready to trade
# trader.run_session()
