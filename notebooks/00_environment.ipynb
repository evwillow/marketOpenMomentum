# %% [markdown]
# # 00 · Environment & Connectivity
#
# Use this notebook once per session to make sure all dependencies are installed, environment variables are loaded, and Alpaca connectivity is healthy.

# %%
# %pip install -q -r ../requirements.txt
print("Dependencies ready.")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Dependencies ready.

# %%
import os
from pathlib import Path

from dotenv import load_dotenv

ENV_PATH = Path("../.env")
if ENV_PATH.exists():
    load_dotenv(ENV_PATH)
    print("Loaded .env file.")
else:
    print(".env file not found. Using existing environment variables.")

required = ["ALPACA_API_KEY", "ALPACA_SECRET_KEY", "ALPACA_BASE_URL"]
missing = [k for k in required if not os.environ.get(k)]
if missing:
    raise RuntimeError(f"Missing credentials: {missing}")
print("Credentials OK.")
# Out:
# Loaded .env file.
# Credentials OK.

# %%
import alpaca_trade_api as tradeapi

api = tradeapi.REST()
clock = api.get_clock()
print(f"Alpaca clock -> is_open={clock.is_open} next_open={clock.next_open}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 import alpaca_trade_api as tradeapi
# ----> 3 api = tradeapi.REST()
#       4 clock = api.get_clock()
#       5 print(f"Alpaca clock -> is_open={clock.is_open} next_open={clock.next_open}")
#
# File c:\Users\evanm\AppData\Local\Programs\Python\Python313\Lib\site-packages\alpaca_trade_api\rest.py:177, in REST.__init__(self, key_id, secret_key, base_url, api_version, oauth, raw_data)
#     165 def __init__(self,
#     166              key_id: str = None,
#     167              secret_key: str = None,
#    (...)    171              raw_data: bool = False
#     172              ):
#     173     """
#     174     :param raw_data: should we return api response raw or wrap it with
#     175                      Entity objects.
#     176     """
# --> 177     self._key_id, self._secret_key, self._oauth = get_credentials(
#     178         key_id, secret_key, oauth)
#     179     self._base_url: URL = URL(base_url or get_base_url())
#     180     self._api_version = get_api_version(api_version)
#
# File c:\Users\evanm\AppData\Local\Programs\Python\Python313\Lib\site-packages\alpaca_trade_api\common.py:84, in get_credentials(key_id, secret_key, oauth)
#      82 key_id = key_id or os.environ.get('APCA_API_KEY_ID')
#      83 if key_id is None and oauth is None:
# ---> 84     raise ValueError('Key ID must be given to access Alpaca trade API',
#      85                      ' (env: APCA_API_KEY_ID)')
#      87 secret_key = secret_key or os.environ.get('APCA_API_SECRET_KEY')
#      88 if secret_key is None and oauth is None:
#
# ValueError: ('Key ID must be given to access Alpaca trade API', ' (env: APCA_API_KEY_ID)')
